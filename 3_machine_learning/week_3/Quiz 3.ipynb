# %%
from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn
from sklearn.model_selection import (
    GridSearchCV,
    train_test_split,
)
from sklearn.svm import SVC
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    precision_recall_curve,
    recall_score,
    precision_score,
    )
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# # fake data

# %% [markdown]
# They don't give you the data set so I made some so I could test the calls I was making (because the quiz hides the errors and just tell you that there was an error on a certain line (almost like using c instead of python)).

# %%
data, labels = make_classification(200, 2, n_redundant=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, random_state=0)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (150, 2)
# (150,)
# (50, 2)
# (50,)

# %% [markdown]
# # Question 1

# %% [markdown]
# A supervised learning model has been built to predict whether someone is infected with a new strain of a virus. The probability of any one person having the virus is 1%. Using accuracy as a metric, what would be a good choice for a baseline accuracy score that the new model would want to outperform?

# %% [markdown]
# I guessed 99, but was marked wrong. Did I use a decimal point?

# %% [markdown]
# try 2: 0.99 (this was correct, I must have used 99 the first time).

# %% [markdown]
# # Question 2

# %% [markdown]
# Given the following confusion matrix:
#
# |                   |Predicted Positive|Predicted Negative|
# |-------------------|------------------|------------------|
# |Condition Positive |96	               | 4                |
# |Condition Negative |8	               |19                |
#
# Compute the accuracy to three decimal places.

# %%
tp = 96
fn = 4
fp = 8
tn = 19

# %%
print("Accuracy: {0:.3f}".format((tp + tn)/(tp + tn + fp + fn)))
# Out:
# Accuracy: 0.906

# %% [markdown]
# # Question 3

# %% [markdown]
# Compute the precision to three decimal places.

# %%
print("Precision: {0:.3f}".format(tp/(tp + fp)))
# Out:
# Precision: 0.923

# %% [markdown]
# # Question 4

# %% [markdown]
# Compute the recall to three decimal places.

# %%
print("Recall: {0:.3f}".format(tp/(tp + fn)))
# Out:
# Recall: 0.960

# %% [markdown]
# # Question 5

# %% [markdown]
# Using the fitted model `m` create a precision-recall curve to answer the following question:
#
# For the fitted model `m`, approximately what precision can we expect for a recall of 0.8?
#
# (Use y_test and X_test to compute the precision-recall curve. If you wish to view a plot, you can use `plt.show()`

# %%
m = LogisticRegression()
m.fit(X_train, y_train)

# %%
plot = plt 
recall_target = 0.8 
y_scores = m.decision_function(X_test)
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)
closest_zero = np.argmin(np.abs(thresholds))
closest_zero_precision = precision[closest_zero]
closest_zero_recall = recall[closest_zero]
index = np.where(np.round(recall, 1)==recall_target)[0][0]
precision_at_recall = precision[index]
print("Precision at recall of {0}: {1}".format(recall_target, precision_at_recall))
figure = plot.figure()
axe = figure.gca()
axe.plot(precision, recall, label="Precision-Recall Curve")
axe.plot(closest_zero_precision, closest_zero_recall, "o", markersize=12, mew=3, fillstyle='none')
axe.set_xlabel("Precision")
axe.set_ylabel("Recall")
axe.axhline(precision_at_recall, color="r")
axe.legend()
title = axe.set_title("Precision vs Recall")
# Out:
# Precision at recall of 0.8: 1.0

# %% [markdown]
# outcome in quiz: precision of 0.55

# %% [markdown]
# **this was once again marked as wrong, although I checke the plot and it looked right to me**.

# %% [markdown]
# # Question 6

# %% [markdown]
# Given the following models and AUC scores, match each model to its corresponding ROC curve.
#
# Model 1 test set AUC score: 0.91
# Model 2 test set AUC score: 0.50
# Model 3 test set AUC score: 0.56

# %%
Image("quiz_roc.png")

# %% [markdown]
# ROC 1, ROC 3, ROC 2

# %% [markdown]
# # Question 7

# %% [markdown]
# Given the following models and accuracy scores, match each model to its corresponding ROC curve.
#
# Model 1 test set accuracy: 0.91
# Model 2 test set accuracy: 0.79
# Model 3 test set accuracy: 0.72

# %%
Image("quiz_roc.png")

# %% [markdown]
# I guessed ROC 1, ROC 2, ROC 3 **but was marked wrong.**

# %% [markdown]
# Take 2 : Not enough information is given

# %% [markdown]
# # Question 8

# %% [markdown]
# Using the fitted model `m` what is the micro precision score?
#
# (Use y_test and X_test to compute the precision score.)

# %%
m = SVC()
m.fit(X_train, y_train)
print(m)
predictions = m.predict(X_test)
print(precision_score(y_test, predictions, average="micro"))
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 0.98

# %% [markdown]
# # Question 9

# %% [markdown]
# Which of the following is true of the R-Squared metric? (Select all that apply)

# %% [markdown]
#  * worst value is 0
#  * best value is 1

# %% [markdown]
# # Question 10

# %% [markdown]
# In a future society, a machine is used to predict a crime before it occurs. If you were responsible for tuning this machine, what evaluation metric would you want to maximize to ensure no innocent people (people not about to commit a crime) are imprisoned (where crime is the positive label)?

# %% [markdown]
# *precision*

# %% [markdown]
# # Question 11

# %% [markdown]
# Consider the machine from the previous question. If you were responsible for tuning this machine, what evaluation metric would you want to maximize to ensure all criminals (people about to commit a crime) are imprisoned (where crime is the positive label)?

# %% [markdown]
# *recall*

# %% [markdown]
# # Question 12

# %% [markdown]
# A classifier is trained on an imbalanced multiclass dataset. After looking at the model’s precision scores, you find that the micro averaging is much smaller than the macro averaging score. Which of the following is most likely happening?

# %% [markdown]
#  It is misclassifying the classes with many instances more than the classes with few instances.

# %% [markdown]
# # Question 13

# %% [markdown]
# Using the already defined RBF SVC model `m`, run a grid search on the parameters C and gamma, for values [0.01, 0.1, 1, 10]. The grid search should find the model that best optimizes for recall. How much better is the recall of this model than the precision? (Compute recall - precision to 3 decimal places)
#
# (Use y_test and X_test to compute precision and recall.)

# %%
m = SVC()
print(m)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
values = [10**power for power in range(-2, 2)]
parameters = dict(C=values, gamma=values)
grid = GridSearchCV(m, parameters, scoring="recall")
grid.fit(X_train, y_train)
predictions = grid.predict(X_test)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(recall - precision)
# Out:
# -0.0344827586207

# %% [markdown]
# # Question 14

# %% [markdown]
# Using the already defined RBF SVC model `m`, run a grid search on the parameters C and gamma, for values [0.01, 0.1, 1, 10]. The grid search should find the model that best optimizes for precision. How much better is the precision of this model than the recall? (Compute precision - recall to 3 decimal places)
#
# (Use y_test and X_test to compute precision and recall.)

# %%
m = SVC()
m.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
values = [10**power for power in range(-2, 2)]
parameters = dict(C=values, gamma=values)
grid = GridSearchCV(m, parameters, scoring="precision")
grid.fit(X_train, y_train)
predictions = grid.predict(X_test)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print(precision - recall)
# Out:
# 0.0689655172414
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/acheron/.virtualenvs/data_science_with_python/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
